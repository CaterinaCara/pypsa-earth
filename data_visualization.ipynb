# %%
import pypsa
import numpy as np
import matplotlib as plt
# Out:
# c:\Users\d094217\AppData\Local\miniconda3\envs\PR-pypsa-earth\lib\site-packages\pypsa\networkclustering.py:16: UserWarning: The namespace `pypsa.networkclustering` is deprecated and will be removed in PyPSA v0.24. Please use `pypsa.clustering.spatial instead`.
#   warnings.warn(

# %%
n = pypsa.Network("results/networks/elec_s_10_ec_lcopt_Co2L-3H.nc")
# Out:
# c:\Users\d094217\AppData\Local\miniconda3\envs\PR-pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# c:\Users\d094217\AppData\Local\miniconda3\envs\PR-pypsa-earth\lib\site-packages\pypsa\components.py:318: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   attrs.loc[bool_b, "default"] = attrs.loc[bool_b].isin({True, "True"})
# ...

# %%
n.storage_units_t.p['IT0 0 PHS']

n.stores['carrier'].unique()
n.storage_units['carrier'].unique() #n.carriers
# Out:
# array(['PHS', 'hydro', 'concrete', 'pair', 'gravity'], dtype=object)

# %%
n.loads_t.p_set
# Out:
# Load                       IT0 0        IT0 1        IT0 2        IT0 3  \
# snapshot
# 2013-01-01 00:00:00  4206.290694  1131.997194  6765.749517  4744.503906
# 2013-01-01 03:00:00  4526.400520  1218.145168  7280.640914  5105.573178
# 2013-01-01 06:00:00  5947.012273  1600.460285  9565.671593  6707.958391
# 2013-01-01 09:00:00  6186.828189  1664.999558  9951.411556  6978.459798
# 2013-01-01 12:00:00  6111.400718  1644.700513  9830.087708  6893.381054
# ...                          ...          ...          ...          ...
# 2013-12-31 09:00:00  6058.782951  1630.540017  9745.452894  6834.030614
# 2013-12-31 12:00:00  5924.029210  1594.275082  9528.703714  6682.034545
# 2013-12-31 15:00:00  6075.892804  1635.144621  9772.973812  6853.329748
# 2013-12-31 18:00:00  5977.344178  1608.623209  9614.459965  6742.171396
# 2013-12-31 21:00:00  4941.959508  1329.980427  7949.060724  5574.304748
#
# Load                       IT0 4        IT0 5        IT0 6        IT0 7  \
# snapshot
# ...
